# %%
import pandas as pd

print("Loading 5 rows...")
df = pd.read_csv('../data/application_train.csv', nrows=5)

print("Data loaded! Here it is:")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 print("Loading 5 rows...")
#       4 df = pd.read_csv('../data/application_train.csv', nrows=5)
#
# ModuleNotFoundError: No module named 'pandas'
